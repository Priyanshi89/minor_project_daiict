# %%
print("This is generator")
# Out:
# This is generator

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import time
import os

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    # Upsample to 14x14
    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    # Upsample to 28x28
    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    return model

# %%
def load_mnist_data():
    (x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()
    x_train = x_train.astype('float32') 
    x_train = (x_train - 127.5) / 127.5  # Normalize to [-1, 1]
    x_train = np.expand_dims(x_train, axis=-1)  # Add channel dimension
    return x_train

# %%
batch_size = 256

# %%
real_images = load_mnist_data()
dataset = tf.data.Dataset.from_tensor_slices(real_images).shuffle(60000).batch(batch_size, drop_remainder=True)

#dataset = tf.data.Dataset.from_tensor_slices(real_images).shuffle(60000).batch(batch_size, drop_reminder = True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
@tf.function
def calculate_error_sum(generated_images, real_images):
    errors = tf.reduce_sum(tf.square(generated_images - real_images))
    return errors

# %%
noise_dim = 100  # Dimension of noise vector
batch_size = 256  # Batch size
epochs = 100     # Total number of epochs

# %%
generator = make_generator_model()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#generator_optimizer = tf.keras.optimizers.Adam(1e-4)
generator_optimizer = tf.keras.optimizers.Adam(1e-4, beta_1=0.5)

# %%
def plot_generated_images(images, epoch):
    plt.figure(figsize=(8, 8))
    for i in range(16):  # Display 16 images
        plt.subplot(4, 4, i + 1)
        plt.imshow(images[i, :, :, 0] * 127.5 + 127.5, cmap='gray')  # Scale back to [0, 255]
        plt.axis('off')
    plt.suptitle(f"Generated Images at Epoch {epoch + 1}")
    plt.show()

# %%
@tf.function
def train_generator_step(target_images):
    noise = tf.random.normal([batch_size, noise_dim])

    with tf.GradientTape() as gen_tape:
        generated_images = generator(noise, training=True)
        # Use calculate_error_sum as the generator's loss
        gen_loss = calculate_error_sum(generated_images, target_images)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    
    return gen_loss

# %%
save_dir = "generator_weights"
os.makedirs(save_dir, exist_ok=True)

# %%
def train_generator_only(dataset, epochs):
    generator_losses = []

    for epoch in range(epochs):
        start = time.time()

        for target_images in dataset:  # Assuming `dataset` provides target images
            gen_loss = train_generator_step(target_images)
            #print(f"{epoch + 1} gen loss : {gen_loss}")
            generator_losses.append(gen_loss.numpy())

        # Calculate the average loss for this epoch
        avg_gen_loss = sum(generator_losses[-len(dataset):]) / len(dataset)

        # Save the generator model weights only every 10 epochs
        if (epoch + 1) % 10 == 0:
            weight_path = os.path.join(save_dir, f"epoch_{epoch+1}.weights.h5")
            generator.save_weights(weight_path)
            print(f"Saved weights for gen_epoch {epoch+1}: {weight_path}")

        # if (epoch + 1) % 10 == 0:
        #     generator.save_weights(f'generator_weights_epoch_{epoch+1}.weights.h5')

        # Optionally generate and save images
        # display.clear_output(wait=True)
        # generate_and_save_images(generator, epoch + 1, seed)

        print('Time for epoch {} is {} sec'.format(epoch + 1, time.time() - start))
        print("Epoch: {}, Generator Loss: {}".format(epoch + 1, avg_gen_loss))

    # Save the generator losses for each epoch to a file
    loss_file_path = os.path.join(os.getcwd(), "Generator_Only_Loss_No_Discriminator.txt")
    with open(loss_file_path, "w") as f:
        for epoch in range(epochs):
            f.write("Epoch: {}, Generator Loss: {}\n".format(epoch + 1, generator_losses[epoch]))

# %%
train_generator_only(dataset, epochs)
# Out:
# Time for epoch 1 is 11.938349962234497 sec
# Epoch: 1, Generator Loss: 68422.7661091079
# Time for epoch 2 is 5.7776939868927 sec
# Epoch: 2, Generator Loss: 54983.40962206197
# Time for epoch 3 is 5.808734655380249 sec
# Epoch: 3, Generator Loss: 54525.81924412393
# Time for epoch 4 is 5.8548903465271 sec
# Epoch: 4, Generator Loss: 54356.22482638889
# Time for epoch 5 is 5.878767728805542 sec
# Epoch: 5, Generator Loss: 54273.267594818375
# Time for epoch 6 is 5.91940450668335 sec
# Epoch: 6, Generator Loss: 54233.90877069979
# Time for epoch 7 is 5.964413166046143 sec
# Epoch: 7, Generator Loss: 54191.85440037393
# Time for epoch 8 is 6.022669792175293 sec
# Epoch: 8, Generator Loss: 54164.81405248398
# Time for epoch 9 is 6.057636976242065 sec
# Epoch: 9, Generator Loss: 54146.59006076389
# Saved weights for gen_epoch 10: generator_weights/epoch_10.weights.h5
# Time for epoch 10 is 6.125751733779907 sec
# Epoch: 10, Generator Loss: 54125.81974492521
# Time for epoch 11 is 6.095349073410034 sec
# Epoch: 11, Generator Loss: 54119.92396167201
# Time for epoch 12 is 6.090860366821289 sec
# Epoch: 12, Generator Loss: 54105.63643496261
# Time for epoch 13 is 6.076264142990112 sec
# Epoch: 13, Generator Loss: 54098.515675080125
# Time for epoch 14 is 6.101754426956177 sec
# Epoch: 14, Generator Loss: 54105.2316539797
# Time for epoch 15 is 6.094731569290161 sec
# Epoch: 15, Generator Loss: 54088.78049879808
# Time for epoch 16 is 6.079420566558838 sec
# Epoch: 16, Generator Loss: 54084.259181356836
# Time for epoch 17 is 6.100773334503174 sec
# Epoch: 17, Generator Loss: 54085.33874198718
# Time for epoch 18 is 6.098130702972412 sec
# Epoch: 18, Generator Loss: 54079.657118055555
# Time for epoch 19 is 6.132264852523804 sec
# Epoch: 19, Generator Loss: 54080.15518162393
# Saved weights for gen_epoch 20: generator_weights/epoch_20.weights.h5
# Time for epoch 20 is 6.186636924743652 sec
# Epoch: 20, Generator Loss: 54071.43063902244
# Time for epoch 21 is 6.164367437362671 sec
# Epoch: 21, Generator Loss: 54069.61964142628
# Time for epoch 22 is 6.191838502883911 sec
# Epoch: 22, Generator Loss: 54073.196364182695
# Time for epoch 23 is 6.22668981552124 sec
# Epoch: 23, Generator Loss: 54065.467247596156
# Time for epoch 24 is 6.242001533508301 sec
# Epoch: 24, Generator Loss: 54066.72165464744
# Time for epoch 25 is 6.238022089004517 sec
# Epoch: 25, Generator Loss: 54059.87449919872
# Time for epoch 26 is 6.205559730529785 sec
# Epoch: 26, Generator Loss: 54059.62389823718
# Time for epoch 27 is 6.217054605484009 sec
# Epoch: 27, Generator Loss: 54057.506660657054
# Time for epoch 28 is 6.225919246673584 sec
# Epoch: 28, Generator Loss: 54059.16573183761
# Time for epoch 29 is 6.222354173660278 sec
# Epoch: 29, Generator Loss: 54055.30114850427
# Saved weights for gen_epoch 30: generator_weights/epoch_30.weights.h5
# Time for epoch 30 is 6.293516397476196 sec
# Epoch: 30, Generator Loss: 54057.06842614851
# Time for epoch 31 is 6.228683233261108 sec
# Epoch: 31, Generator Loss: 54054.56555488782
# Time for epoch 32 is 6.24320125579834 sec
# Epoch: 32, Generator Loss: 54052.28994724893
# Time for epoch 33 is 6.252926349639893 sec
# Epoch: 33, Generator Loss: 54046.475160256414
# Time for epoch 34 is 6.249887228012085 sec
# Epoch: 34, Generator Loss: 54050.93000467415
# Time for epoch 35 is 6.260195970535278 sec
# Epoch: 35, Generator Loss: 54046.535389957266
# Time for epoch 36 is 6.26099419593811 sec
# Epoch: 36, Generator Loss: 54044.95234041133
# Time for epoch 37 is 6.2421159744262695 sec
# Epoch: 37, Generator Loss: 54043.4132946047
# Time for epoch 38 is 6.26045036315918 sec
# Epoch: 38, Generator Loss: 54046.788261217946
# Time for epoch 39 is 6.265653133392334 sec
# Epoch: 39, Generator Loss: 54041.53266893697
# Saved weights for gen_epoch 40: generator_weights/epoch_40.weights.h5
# Time for epoch 40 is 6.295356273651123 sec
# Epoch: 40, Generator Loss: 54047.90441372863
# Time for epoch 41 is 6.26880145072937 sec
# Epoch: 41, Generator Loss: 54047.41421274038
# Time for epoch 42 is 6.262456893920898 sec
# Epoch: 42, Generator Loss: 54037.75405649038
# Time for epoch 43 is 6.2686543464660645 sec
# Epoch: 43, Generator Loss: 54038.99641092415
# Time for epoch 44 is 6.272311449050903 sec
# Epoch: 44, Generator Loss: 54039.10122863248
# Time for epoch 45 is 6.272259712219238 sec
# Epoch: 45, Generator Loss: 54036.120008680555
# Time for epoch 46 is 6.281078100204468 sec
# Epoch: 46, Generator Loss: 54036.999165331195
# Time for epoch 47 is 6.27794075012207 sec
# Epoch: 47, Generator Loss: 54042.565604967946
# Time for epoch 48 is 6.284700393676758 sec
# Epoch: 48, Generator Loss: 54037.80039730235
# Time for epoch 49 is 6.283447504043579 sec
# Epoch: 49, Generator Loss: 54034.63262887286
# Saved weights for gen_epoch 50: generator_weights/epoch_50.weights.h5
# Time for epoch 50 is 6.333687782287598 sec
# Epoch: 50, Generator Loss: 54036.47447582799
# Time for epoch 51 is 6.291372060775757 sec
# Epoch: 51, Generator Loss: 54039.96130475427
# Time for epoch 52 is 6.308115720748901 sec
# Epoch: 52, Generator Loss: 54036.10778912927
# Time for epoch 53 is 6.30525279045105 sec
# Epoch: 53, Generator Loss: 54032.51055021367
# Time for epoch 54 is 6.328024625778198 sec
# Epoch: 54, Generator Loss: 54032.7191673344
# Time for epoch 55 is 6.3494791984558105 sec
# Epoch: 55, Generator Loss: 54033.65940504808
# Time for epoch 56 is 6.327965259552002 sec
# Epoch: 56, Generator Loss: 54035.645616319445
# Time for epoch 57 is 6.3136091232299805 sec
# Epoch: 57, Generator Loss: 54030.8218482906
# Time for epoch 58 is 6.317856550216675 sec
# Epoch: 58, Generator Loss: 54032.9851428953
# Time for epoch 59 is 6.304582834243774 sec
# Epoch: 59, Generator Loss: 54034.31401909722
# Saved weights for gen_epoch 60: generator_weights/epoch_60.weights.h5
# Time for epoch 60 is 6.332543134689331 sec
# Epoch: 60, Generator Loss: 54034.973524305555
# Time for epoch 61 is 6.301925420761108 sec
# Epoch: 61, Generator Loss: 54030.73844818376
# Time for epoch 62 is 6.299546241760254 sec
# Epoch: 62, Generator Loss: 54028.251151842946
# Time for epoch 63 is 6.321820497512817 sec
# Epoch: 63, Generator Loss: 54028.738832131414
# Time for epoch 64 is 6.328279972076416 sec
# Epoch: 64, Generator Loss: 54026.52632545406
# Time for epoch 65 is 6.324226379394531 sec
# Epoch: 65, Generator Loss: 54032.96918402778
# Time for epoch 66 is 6.326310396194458 sec
# Epoch: 66, Generator Loss: 54029.43579727564
# Time for epoch 67 is 6.307000398635864 sec
# Epoch: 67, Generator Loss: 54026.9976963141
# Time for epoch 68 is 6.319933652877808 sec
# Epoch: 68, Generator Loss: 54029.198734642094
# Time for epoch 69 is 6.315342664718628 sec
# Epoch: 69, Generator Loss: 54031.3609107906
# Saved weights for gen_epoch 70: generator_weights/epoch_70.weights.h5
# Time for epoch 70 is 6.342267274856567 sec
# Epoch: 70, Generator Loss: 54025.328675881414
# Time for epoch 71 is 6.312557220458984 sec
# Epoch: 71, Generator Loss: 54026.003455528844
# Time for epoch 72 is 6.3348681926727295 sec
# Epoch: 72, Generator Loss: 54031.13426482372
# Time for epoch 73 is 6.311295032501221 sec
# Epoch: 73, Generator Loss: 54028.968299278844
# Time for epoch 74 is 6.3248515129089355 sec
# Epoch: 74, Generator Loss: 54024.77300347222
# Time for epoch 75 is 6.326010465621948 sec
# Epoch: 75, Generator Loss: 54024.40493122329
# Time for epoch 76 is 6.327517509460449 sec
# Epoch: 76, Generator Loss: 54024.95769898504
# Time for epoch 77 is 6.324957609176636 sec
# Epoch: 77, Generator Loss: 54027.20631343483
# Time for epoch 78 is 6.319054365158081 sec
# Epoch: 78, Generator Loss: 54026.10391626602
# Time for epoch 79 is 6.331841707229614 sec
# Epoch: 79, Generator Loss: 54022.56542134081
# Saved weights for gen_epoch 80: generator_weights/epoch_80.weights.h5
# Time for epoch 80 is 6.344430446624756 sec
# Epoch: 80, Generator Loss: 54025.79395365919
# Time for epoch 81 is 6.337002992630005 sec
# Epoch: 81, Generator Loss: 54024.54976295406
# Time for epoch 82 is 6.326618432998657 sec
# Epoch: 82, Generator Loss: 54023.390608306625
# Time for epoch 83 is 6.329516172409058 sec
# Epoch: 83, Generator Loss: 54026.720252403844
# Time for epoch 84 is 6.323044300079346 sec
# Epoch: 84, Generator Loss: 54022.85308159722
# Time for epoch 85 is 6.342436075210571 sec
# Epoch: 85, Generator Loss: 54027.37169471154
# Time for epoch 86 is 6.328690528869629 sec
# Epoch: 86, Generator Loss: 54017.939436431625
# Time for epoch 87 is 6.31357479095459 sec
# Epoch: 87, Generator Loss: 54026.34127938034
# Time for epoch 88 is 6.316580772399902 sec
# Epoch: 88, Generator Loss: 54024.13835470085
# Time for epoch 89 is 6.299833297729492 sec
# Epoch: 89, Generator Loss: 54021.08406784188
# Saved weights for gen_epoch 90: generator_weights/epoch_90.weights.h5
# Time for epoch 90 is 6.320084095001221 sec
# Epoch: 90, Generator Loss: 54023.36561832265
# Time for epoch 91 is 6.29393744468689 sec
# Epoch: 91, Generator Loss: 54018.86334802351
# Time for epoch 92 is 6.29262638092041 sec
# Epoch: 92, Generator Loss: 54016.16506410256
# Time for epoch 93 is 6.303501844406128 sec
# Epoch: 93, Generator Loss: 54028.620292467946
# Time for epoch 94 is 6.311473369598389 sec
# Epoch: 94, Generator Loss: 54022.749348958336
# Time for epoch 95 is 6.3058977127075195 sec
# Epoch: 95, Generator Loss: 54018.22033587073
# Time for epoch 96 is 6.29793906211853 sec
# Epoch: 96, Generator Loss: 54019.301332131414
# Time for epoch 97 is 6.311927318572998 sec
# Epoch: 97, Generator Loss: 54025.37525040064
# Time for epoch 98 is 6.297634124755859 sec
# Epoch: 98, Generator Loss: 54020.20693108974
# Time for epoch 99 is 6.297758102416992 sec
# Epoch: 99, Generator Loss: 54018.47283987714
# Saved weights for gen_epoch 100: generator_weights/epoch_100.weights.h5
# Time for epoch 100 is 6.329143047332764 sec
# Epoch: 100, Generator Loss: 54022.45025373931
